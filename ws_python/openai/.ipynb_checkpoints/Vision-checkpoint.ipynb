# %% [markdown]
# # Computer vision

# %% [markdown]
# ## 이미지 생성

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\programdata\anaconda3\envs\ai\lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: tensorflow-intel

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 1.50.2
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: c:\users\chatgpt\appdata\roaming\python\python310\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
# Google Colab 환경에서 Google Drive를 사용하려면, 먼저 Google Drive를 마운트해야 한다.
# '/content/drive'는 Google Drive가 마운트될 경로
# 이 경로를 통해 Google Drive의 파일에 접근할 수 있다.
# 'drive.mount' 메서드는 인증 프로세스를 시작하며, Google 계정에 대한 접근 권한을 요청한다.
# 이 과정에서 제공된 링크를 클릭하고 인증 코드를 입력해야 한다.
import os
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/My Drive/openai/' # Colab

os.chdir(path) # 기본 경로 설정

# %%
import os
# 주피터에서
# api_key=os.environ['OPENAI_API_KEY']
# 'GPT_Key.txt' 파일에서 API 키 읽기 : 코렙에서
with open("./GPT_Key.txt", "r") as f:
    api_key = f.read().strip()

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key) # OPENAI_API_KEY 기본 키 찾음

# prompt = '난 한국인이야, 가족과 같이 먹을 저녁 메뉴로 한우 등심 이미지를 생성해줘.'
prompt = 'I am Korean. Please create an image of Korean beef sirloin for dinner with my family.'
# OpenAI 클라이언트를 사용하여 이미지 생성 요청을 보냄
response = client.images.generate(
    model="dall-e-3",  # 사용할 모델 이름 (DALL-E 3)
    prompt=prompt,      # 이미지 생성을 위한 설명 (프롬프트)
    size = "1024x1024",   # 생성할 이미지의 크기
    quality = "standard",  # 생성할 이미지의 품질 설정
    n=1,                # 생성할 이미지의 개수 (여기서는 1개)
)


image_url = response.data[0].url

# %%
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-NIpG16oV4WZavldiRcRj5xGG/user-BGS7jtgt6emT9nJpqJUtDOev/img-1pVXcTLI2h9dWnwDwHCl1CLN.png?st=2024-10-12T03%3A19%3A07Z&se=2024-10-12T05%3A19%3A07Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-11T23%3A11%3A22Z&ske=2024-10-12T23%3A11%3A22Z&sks=b&skv=2024-08-04&sig=XYjyD1Gq0ICix74pCT%2BXxWiNG2shxd7WJgM4eEiccvQ%3D

# %% [markdown]
# ## 이미지 출력

# %%
# !pip show requests

# %%
import os
import random
import requests
from datetime import datetime

import json

from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

import tool  # tool.py

from openai import OpenAI
client = OpenAI(api_key=api_key) # OPENAI_API_KEY 기본 키 찾음

# %%
# prompt = '난 한국인이야, 가족과 같이 먹을 저녁 메뉴로 한우 등심 이미지를 생성해줘.'
# prompt = 'I am Korean. Please create an image of Korean beef sirloin for dinner with my family.'
prompt = '난 한국인이야, 시원한 계곡 이미지 생성해줘.'
response = client.images.generate(
    model="dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="standard",
    n=1    
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-NIpG16oV4WZavldiRcRj5xGG/user-BGS7jtgt6emT9nJpqJUtDOev/img-LaORI78SbfDgmdKUAjR87ttn.png?st=2024-10-12T04%3A45%3A32Z&se=2024-10-12T06%3A45%3A32Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-11T23%3A06%3A50Z&ske=2024-10-12T23%3A06%3A50Z&sks=b&skv=2024-08-04&sig=CHbpdyarNpqun4hmOTTZEY1USXgicGz30ntvMeBPQYs%3D

# %%
import requests
# URL에서 이미지를 가져옴
response = requests.get(image_url)
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# 응답이 성공적인지 확인
if response.status_code == 200:
    # 이미지 데이터를 바이트로 읽어옴
    image_data = Image.open(BytesIO(response.content))
    print(type(image_data)) # <class 'PIL.PngImagePlugin.PngImageFile'>

    # 이미지 표시
    plt.imshow(image_data)
    plt.axis('off')  # 축을 표시하지 않도록 설정
    plt.show()
else:
    print("이미지를 가져오는데 문제가 발생했습니다.")
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %% [markdown]
# ## 영어로 번역 + 이미지 생성 + 이미지 출력

# %%
# 영어로 번역
sentence = '한겨울 스위스의 시골 마을의 저녁 풍경 이미지 생성해줘.'
prompt = f'아래 문장을 영어로 번역해줘.\n\n{sentence}'
print('-> prompt: ' + prompt)

format = '''
{
  "res": "번역된 문장"
}
'''

response = tool.answer('너는 번역기야', prompt, format) # gpt-3.5-turbo
print(response['res'])



# 이미지 생성
prompt = response['res']
response = client.images.generate(
    model="dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="standard",
    n=1   
)

image_url = response.data[0].url
print(image_url)

# 이미지 출력
# URL에서 이미지를 가져옴

response = requests.get(image_url)

# 응답이 성공적인지 확인
if response.status_code == 200:
    # 이미지 데이터를 바이트로 읽어옴
    image_data = Image.open(BytesIO(response.content))
    print(type(image_data)) # <class 'PIL.PngImagePlugin.PngImageFile'>

    # 이미지 표시
    plt.imshow(image_data)
    plt.axis('off')  # 축을 표시하지 않도록 설정
    plt.show()
else:
    print("이미지를 가져오는데 문제가 발생했습니다.")
# Out:
# -> prompt: 아래 문장을 영어로 번역해줘.
#
# 한겨울 스위스의 시골 마을의 저녁 풍경 이미지 생성해줘.
# Generate an image of an evening landscape in a rural village in Switzerland during the middle of winter.
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-NIpG16oV4WZavldiRcRj5xGG/user-BGS7jtgt6emT9nJpqJUtDOev/img-DjqPVIaQTUFTLmhrVrDoa0YK.png?st=2024-10-12T04%3A55%3A56Z&se=2024-10-12T06%3A55%3A56Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-11T23%3A18%3A29Z&ske=2024-10-12T23%3A18%3A29Z&sks=b&skv=2024-08-04&sig=jQBWJimICSNFfosfzArzwA/rcUEo5b5UKFT7/KZKNZo%3D
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %% [markdown]
# ## 영어로 번역 + 이미지 생성 + 이미지 출력 + 이미지 저장

# %%
# 영어로 번역
sentence = '난 한국인이야, 잣나무가 5그루 정도 있고 다람쥐가 있는 이미지 생성해줘.'
# sentence = '난 한국인이야, 서울 시청 광장이 포함된 독서 대회 포스터 이미지를 3D로 생성해줘, 한글로 소개도 포함해줘.'
prompt = f'아래 문장을 영어로 번역해줘.\n\n{sentence}'
print('-> prompt: ' + prompt)

format = '''
{
  "res": "번역된 문장"
}
'''

response = tool.answer('너는 번역기야', prompt, format) # gpt-3.5-turbo
print(response['res'])

# 이미지 생성
prompt = response['res']
response = client.images.generate(
  model="dall-e-3",
  prompt=prompt,
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url
print(image_url)

# 이미지 출력
# URL에서 이미지를 가져옴
response = requests.get(image_url)

# 응답이 성공적인지 확인
if response.status_code == 200:
    # 이미지 데이터를 바이트로 읽어옴
    image_data = Image.open(BytesIO(response.content))
    print(type(image_data)) # <class 'PIL.PngImagePlugin.PngImageFile'>

    # 이미지 표시
    plt.imshow(image_data)
    plt.axis('off')  # 축을 표시하지 않도록 설정
    plt.show()
else:
    print("이미지를 가져오는데 문제가 발생했습니다.")
# Out:
# -> prompt: 아래 문장을 영어로 번역해줘.
#
# 난 한국인이야, 잣나무가 5그루 정도 있고 다람쥐가 있는 이미지 생성해줘.
# I am Korean, please generate an image with about five pine trees and a squirrel.
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-NIpG16oV4WZavldiRcRj5xGG/user-BGS7jtgt6emT9nJpqJUtDOev/img-PK4XlpbF6sLwtiny3t8XeS3N.png?st=2024-10-12T05%3A02%3A54Z&se=2024-10-12T07%3A02%3A54Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-11T23%3A11%3A22Z&ske=2024-10-12T23%3A11%3A22Z&sks=b&skv=2024-08-04&sig=W/0DXJqMQ9efdwbi7a3GTXgrW/v27UNa2AysiCylK9Q%3D
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
from datetime import datetime
import random
import os

# 이미지 저장
# --------------------------------------------------------------------------------------
# 현재 시간을 가져옴
now = datetime.now()
print(now)

# '년월일시분초' 형식의 문자열 생성, 대소문자 구분
date_time_string = now.strftime("%Y%m%d%H%M%S")

# 1부터 1000까지의 난수 생성
random_number = random.randint(1, 1000)

if os.path.exists('./static/storage') == False:
    os.makedirs('./static/storage') # 폴더 생성

# 파일명 생성 (년월일시분초_난수.txt 형식)
file_name = f"./static/storage/{date_time_string}_{random_number}.jpg"

# 응답이 성공적인지 확인
if response.status_code == 200:
    # 이미지 데이터를 파일로 저장
    with open(file_name, "wb") as file:
        file.write(response.content)
    print("이미지가 성공적으로 저장되었습니다.")
else:
    print("이미지를 가져오는데 문제가 발생했습니다.")
# Out:
# 2024-10-12 15:07:06.010226
# 이미지가 성공적으로 저장되었습니다.

# %% [markdown]
# ## 이미지 인식

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "이미지 설명해줘."},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=500,
)

print(response.choices[0])
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지에는 넓은 초원과 나무들이 있는 평화로운 풍경이 보여요. 중앙에 나무로 만들어진 길이 초원을 가로질러 뻗어 있으며, 양옆으로는 푸른 풀들이 자 growing있고, 멀리에는 구름이 드리운 푸른 하늘이 나타나 있습니다. 이 장면은 자연의 아름다움과 고요함을 잘 전달하고 있습니다.', refusal=None, role='assistant', function_call=None, tool_calls=None))

# %%
print(response.choices[0].message.content)
# Out:
# 이미지에는 넓은 초원과 나무들이 있는 평화로운 풍경이 보여요. 중앙에 나무로 만들어진 길이 초원을 가로질러 뻗어 있으며, 양옆으로는 푸른 풀들이 자 growing있고, 멀리에는 구름이 드리운 푸른 하늘이 나타나 있습니다. 이 장면은 자연의 아름다움과 고요함을 잘 전달하고 있습니다.

# %% [markdown]
# ## 이미지 업로드 및 이미지 인식

# %%
import os
import base64
import requests

# 이미지 파일을 입력받아서 이미지 인코딩
# Function to encode the image
def encode_image(image_path): # 이미지 읽기
  with open(image_path, "rb") as image_file: #r은 read, b는 byte. 바이너리 단위로 이미지를 읽기
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "./static/storage/food4.jpg"

# Getting the base64 string
base64_image = encode_image(image_path) # 이미지를 코드화

headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

prompt = "메뉴 알려줘"

format = '''
{
  "res": "메뉴명"
}
'''

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
      messages= [
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": prompt + '\n\n출력 형식: ' + format
            },
            {
              "type": "image_url",
              "image_url": {
                "url": f"data:image/jpeg;base64,{base64_image}"
              }
            }
          ]
        }
      ],
      max_tokens= 300

)


payload = {
  "model": "gpt-4o-mini-2024-07-18",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": prompt + '\n\n출력 형식: ' + format
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

# print(response.json()['choices'][0])
print(response.json()['choices'][0]['message']['content'])

# {'id': 'chatcmpl-9WEngL3UnM7Uz2SejrHf5X8lY8J3o', 'object': 'chat.completion', 'created': 1717470416, 'model': 'gpt-4o-2024-05-13', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "이 사진은 '부대찌개'라는 한국 요리입니다. 부대찌개는 다양한 재료가 들어간 매운 국물 요리로, 흔히 햄, 소시지, 두부, 면, 콩, 파 등의 재료가 포함됩니다. 이 사진에서 보이는 재료는 다음과 같습니다:\n\n- 소시지\n- 햄\n- 다양한 채소 (버섯, 파, 고추 등)\n- 김치\n- 치즈\n- 마카로니\n- 면\n\n부대찌개는 고추장과 함께 매운맛을 내는 국물에 끓여 먹는 요리입니다."}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 776, 'completion_tokens': 140, 'total_tokens': 916}, 'system_fingerprint': 'fp_aa87380ac5'}
# 1
# Out:
# {
#   "res": "라면"
# }

# %%
print(type(response.json()['choices'][0]['message']['content']))
print(response.json()['choices'][0]['message']['content'])
res = response.json()['choices'][0]['message']['content']
json_obj = json.loads(res)
# print(json_obj)
print(f"메뉴명: {json_obj['res']}")
# Out:
# <class 'str'>
# {
#   "res": "라면"
# }
# 메뉴명: 라면

# %% [markdown]
# ## 이미지 업로드 + 메뉴 인식 + 제작 방법 + 맛집 추천

# %%
# import os
# import base64
# import requests

# # Function to encode the image
# def encode_image(image_path): # 이미지 읽기
#   with open(image_path, "rb") as image_file:
#     return base64.b64encode(image_file.read()).decode('utf-8')


# Path to your image
image_path = "./static/storage/food1.jpg"

# Getting the base64 string
base64_image = encode_image(image_path) # 이미지를 코드화

# headers = {
#   "Content-Type": "application/json",
#   "Authorization": f"Bearer {api_key}"
# }

prompt = "메뉴 알려줘"

format = '''
{
  "res": "메뉴명"
}
'''

# payload = {
#   "model": "gpt-4o-mini-2024-07-18",
#   "messages": [
#     {
#       "role": "user",
#       "content": [
#         {
#           "type": "text",
#           "text": prompt + '\n\n출력 형식: ' + format
#         },
#         {
#           "type": "image_url",
#           "image_url": {
#             "url": f"data:image/jpeg;base64,{base64_image}"
#           }
#         }
#       ]
#     }
#   ],
#   "max_tokens": 300
# }

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
      messages= [
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": prompt + '\n\n출력 형식: ' + format
            },
            {
              "type": "image_url",
              "image_url": {
                "url": f"data:image/jpeg;base64,{base64_image}"
              }
            }
          ]
        }
      ],
      max_tokens= 300

)


response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

res = response.json()['choices'][0]['message']['content']
json_obj = json.loads(res)
menu = json_obj['res'] # 메뉴명
print(f"메뉴명: {menu}")

prompt = menu + ' 맛있게 만드는 방법 알려줘'
format = '''
{
  "res": "메뉴 제작 방법"
}
'''

response = tool.answer('너는 한국 음식 요리사야', prompt, format)
print('-' * 80)
print('레시피 제작 방법')
print(response['res'])

prompt = '힌국 종로구에서 ' + menu + ' 맛있게 판매하는 맛집 식당 알려줘'
format = '''
{
  "res": "추천 맛집 목록"
}
'''

response = tool.answer('너는 한국 맛집 안내 가이드야', prompt, format)
print('-' * 80)
print('추천 맛집 목록')
print(response['res'])
# Out:
# 메뉴명: 라면
# --------------------------------------------------------------------------------
# 레시피 제작 방법
# 1. 물 끓이기: 냄비에 500ml의 물을 붓고 끓입니다.
# 2. 면 넣기: 물이 끓기 시작하면 라면 면을 넣고 3-4분간 끓입니다.
# 3. 스프 추가: 면이 익기 시작하면 라면 스프를 넣고 잘 저어줍니다.
# 4. 추가 재료: 기호에 따라 계란, 대파, 김치, 치즈 등을 추가하여 함께 끓입니다.
# 5. 마무리: 모든 재료가 잘 섞이고 면이 익으면 불을 끄고 그릇에 담아냅니다.
# 6. 즐기기: 뜨거운 라면을 맛있게 즐기세요!
# --------------------------------------------------------------------------------
# 추천 맛집 목록
# [{'name': '신라면옥', 'address': '서울 종로구 종로 1길 50', 'description': '신라면을 활용한 다양한 라면 요리를 제공하는 곳으로, 깊고 진한 국물 맛이 일품입니다.'}, {'name': '라면공방', 'address': '서울 종로구 종로 5가 123', 'description': '수제 면과 신선한 재료로 만든 라면을 즐길 수 있는 곳으로, 다양한 토핑이 매력적입니다.'}, {'name': '라면집', 'address': '서울 종로구 청계천로 100', 'description': '전통적인 한국식 라면을 현대적으로 재해석한 메뉴가 특징이며, 아늑한 분위기에서 식사할 수 있습니다.'}, {'name': '명동교자', 'address': '서울 종로구 명동 10길 29', 'description': '칼국수로 유명하지만, 라면도 인기 메뉴로, 진한 국물과 쫄깃한 면발이 매력적입니다.'}]

# %% [markdown]
# ## 이미지 업로드 + 이미지 변경
# - 2024-06-22 실행안됨
# - OpenAI Plus 유료 구독의 경우 이미지를 2장을 업로드한후 결합하여 출력하는 기능 제공.
# - 예) 꽃 이미지, 책상 이미지 -> 책상의 꽃병에 업로드한 꽃이 놓여있도록 배치해줘 -> 책상위에 꽃이 추가되어 다운로드 가능함.

# %%
import os
import base64
import requests


# Function to encode the image
def encode_image(image_path): # 이미지 읽기
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "./static/storage/food4.jpg" # 라면

# Getting the base64 string
base64_image = encode_image(image_path) # 이미지를 코드화

headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

prompt = "라면 이미지에 대파와 계란을 추가해서 이미지를 생성해줘"

format = '''
생성된 이미지 주소
'''

payload = {
  "model": "gpt-4o",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": prompt + '\n\n출력 형식: ' + format
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

print(response.json()['choices'][0])
# print(response.json()['choices'][0]['message']['content'])

# {'id': 'chatcmpl-9WEngL3UnM7Uz2SejrHf5X8lY8J3o', 'object': 'chat.completion', 'created': 1717470416, 'model': 'gpt-4o-2024-05-13', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "이 사진은 '부대찌개'라는 한국 요리입니다. 부대찌개는 다양한 재료가 들어간 매운 국물 요리로, 흔히 햄, 소시지, 두부, 면, 콩, 파 등의 재료가 포함됩니다. 이 사진에서 보이는 재료는 다음과 같습니다:\n\n- 소시지\n- 햄\n- 다양한 채소 (버섯, 파, 고추 등)\n- 김치\n- 치즈\n- 마카로니\n- 면\n\n부대찌개는 고추장과 함께 매운맛을 내는 국물에 끓여 먹는 요리입니다."}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 776, 'completion_tokens': 140, 'total_tokens': 916}, 'system_fingerprint': 'fp_aa87380ac5'}
# 1
# Out:
# {'index': 0, 'message': {'role': 'assistant', 'content': '죄송하지만 이미지를 직접 생성할 수는 없습니다. 대신, 라면에 대파와 계란을 추가하여 편집된 이미지를 온라인 편집 도구를 사용해 만들어 보실 수 있습니다. 이미지 편집 도구를 추천해드릴 수 있으니 말씀해 주세요!', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}
